# %% [markdown]
# # Prácticas de Computer Vision

# %%
# Establecemos nuestras credenciales
key='ddc744e8705441dba7d6c5161b4e66a7'
endpoint='https://cv-dr-lablab1.cognitiveservices.azure.com/'

# %%
# Conectamos con azure
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from msrest.authentication import CognitiveServicesCredentials

client = ComputerVisionClient(endpoint, CognitiveServicesCredentials(key))

# %%
import vision
import os

# %matplotlib inline

# Obtenemos la imagen
image_path='./data/vision/imagen1.jpg'

image_stream = open(image_path, "rb")
description =  client.describe_image_in_stream(image_stream)
print(description)

vision.show_image_caption(image_path, description)
# Out:
# {'additional_properties': {}, 'tags': ['water', 'animal', 'reptile', 'outdoor', 'crocodilian reptile', 'lake', 'pond', 'swimming'], 'captions': [<azure.cognitiveservices.vision.computervision.models._models_py3.ImageCaption object at 0x000002CF1D262980>], 'request_id': 'df296e9b-e75f-4c63-9ff5-7dcecad0ea73', 'metadata': <azure.cognitiveservices.vision.computervision.models._models_py3.ImageMetadata object at 0x000002CF1D261F60>, 'model_version': '2021-05-01'}

# %%
image_path = './data/vision/imagen2.jpg'

image_stream = open(image_path, "rb")
description = client.describe_image_in_stream(image_stream)

vision.show_image_caption(image_path, description)

# %%
# Obtenemos la imagen
image_path='./data/vision/imagen3.jpg'

features = ['description' , 'tags' , 'adult' , 'objects' , 'faces']

image_stream = open(image_path, "rb")
analysis = client.analyze_image_in_stream(image_stream, visual_features=features)

vision.show_image_analysis(image_path, analysis)

# %% [markdown]
# ## FaceAPI

# %%
# %pip install azure.cognitiveservices.vision.face
# Out:
# Requirement already satisfied: azure.cognitiveservices.vision.face in c:\users\windows 10\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.6.0)
# Requirement already satisfied: msrest>=0.5.0 in c:\users\windows 10\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from azure.cognitiveservices.vision.face) (0.7.0)
# Requirement already satisfied: azure-common~=1.1 in c:\users\windows 10\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from azure.cognitiveservices.vision.face) (1.1.28)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\users\windows 10\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from msrest>=0.5.0->azure.cognitiveservices.vision.face) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\windows 10\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from msrest>=0.5.0->azure.cognitiveservices.vision.face) (2022.5.18.1)
# Requirement already satisfied: isodate>=0.6.0 in c:\users\windows 10\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from msrest>=0.5.0->azure.cognitiveservices.vision.face) (0.6.1)
# Requirement already satisfied: requests~=2.16 in c:\users\windows 10\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from msrest>=0.5.0->azure.cognitiveservices.vision.face) (2.28.0)
# Requirement already satisfied: azure-core>=1.24.0 in c:\users\windows 10\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from msrest>=0.5.0->azure.cognitiveservices.vision.face) (1.24.1)
# Requirement already satisfied: six>=1.11.0 in c:\users\windows 10\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from azure-core>=1.24.0->msrest>=0.5.0->azure.cognitiveservices.vision.face) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.0.1 in c:\users\windows 10\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from azure-core>=1.24.0->msrest>=0.5.0->azure.cognitiveservices.vision.face) (4.2.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\windows 10\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests~=2.16->msrest>=0.5.0->azure.cognitiveservices.vision.face) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\windows 10\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests~=2.16->msrest>=0.5.0->azure.cognitiveservices.vision.face) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\windows 10\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests~=2.16->msrest>=0.5.0->azure.cognitiveservices.vision.face) (2.0.12)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\windows 10\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.0->azure.cognitiveservices.vision.face) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
key ='1b986005db56425196648b6cc6532552'
endpoint = 'https://face-dr-lab2.cognitiveservices.azure.com/'

# %%
# Conectamos con azure
from azure.cognitiveservices.vision.face import FaceClient
from msrest.authentication import CognitiveServicesCredentials

client = FaceClient(endpoint, CognitiveServicesCredentials(key))

# %%
import faces
import os
# %matplotlib inline

# %%
image_path='./data/vision/imagen4.jpg'
image_stream = open(image_path, "rb")

detected_faces = client.face.detect_with_stream(image=image_stream)

faces.show_faces(image_path, detected_faces)

# %%
image_path='./data/vision/imagen4.jpg'
image_stream = open(image_path, "rb")

detected_faces = client.face.detect_with_stream(image=image_stream)

faces.show_faces(image_path, detected_faces, show_id=True)

# %%
image_path='./data/vision/imagen4.jpg'
image_stream = open(image_path, "rb")

attributes = ['age' , 'emotion']
detected_faces = client.face.detect_with_stream(image=image_stream, return_face_attributes=attributes)

faces.show_face_attributes(image_path, detected_faces)
